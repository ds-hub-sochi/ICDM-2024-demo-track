# %%
import numpy as np
slovo_np = np.load('/home/jovyan/murtazin/slt_mae/ckpts/SLOVO_LS_rnd_smpl_betta_0.5.npy')

# %%
slovo_np.shape
# Out:
# (1001, 1001)

# %%
slovo_np.dtype
# Out:
# dtype('float64')

# %%
gsl_np = np.load('/home/jovyan/murtazin/slt_mae/ckpts/GSL_LS_rnd_smpl_betta_0.5.npy')
gsl_np.shape
gsl_np.dtype
# Out:
# dtype('float64')

# %%
gsl_np[0]
# Out:
# array([9.00000000e-01, 1.11489258e-03, 7.02189714e-04, 1.35552710e-04,
#        6.13259294e-05, 1.93814494e-04, 2.06745684e-02, 1.26875694e-03,
#        1.02169077e-03, 3.81960952e-04, 1.04098310e-04, 8.38422033e-05,
#        2.63316547e-05, 1.34010004e-04, 1.38230116e-04, 7.21028723e-05,
#        1.16843635e-04, 3.02796494e-04, 4.29067743e-05, 4.43964549e-04,
#        1.00612562e-03, 1.19888985e-04, 1.54235797e-04, 7.88096759e-05,
#        1.18088945e-04, 1.74265466e-04, 5.44321483e-04, 3.24899710e-04,
#        3.60455807e-05, 1.54320182e-04, 1.72981002e-04, 1.04471576e-04,
#        6.27714744e-05, 1.39521767e-04, 4.13600693e-04, 2.00966113e-04,
#        2.47718822e-04, 2.66493246e-04, 2.03069989e-04, 3.59739845e-04,
#        9.71593155e-06, 1.87077671e-04, 6.95935347e-05, 3.81037187e-05,
#        3.62510385e-04, 6.19448468e-05, 4.02375948e-04, 1.84902390e-04,
#        7.25809369e-05, 1.52458994e-04, 2.41228137e-04, 3.57463758e-05,
# ...

# %%
slovo_np[0]
# Out:
# array([9.00000000e-01, 8.79260873e-05, 1.05613269e-05, ...,
#        2.87969404e-05, 1.11551204e-03, 9.23045329e-05])
